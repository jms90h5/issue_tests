# %% [markdown]
# Basic Interactor Demo
# ---------------------
#
# This demo shows off an interactive visualization using [Bokeh](http://bokeh.pydata.org) for plotting, and Ipython interactors for widgets. The demo runs entirely inside the Ipython notebook, with no Bokeh server required.
#
# The dropdown offers a choice of trig functions to plot, and the sliders control the frequency, amplitude, and phase.
#
# To run, click on, `Cell->Run All` in the top menu, then scroll to the bottom and move the sliders.

# %% [markdown]
# This is slightly modified version of the interact_basic notebook that demonstrates a problem with v0.11.1 where the interaction of a notebook stops working if a CustomJS callback is registered that attempts to retrieve the selection and the user clicks the chart reset button. (There are other conditions that will trigger the behavior but this is the simplest one to recreate. I see the same behavior in a different application if I do something like a box zoom or select instead of a reset (although interestingly in this small example that doesn't seem to cause the problem.) The error reported in the javascript error is "Cannot read property 'indices' of undefined".

# %%
from ipywidgets import interact
import numpy as np

import bokeh 
from bokeh.io import push_notebook
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import CustomJS, BoxSelectTool, LassoSelectTool, PolySelectTool, TapTool
print('bokeh version: %s' %  bokeh.__version__)
# Out:
# bokeh version: 0.11.1

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d5bb9bd2-002a-4888-89f4-f398eeae5e61">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
p.add_tools(LassoSelectTool(), PolySelectTool(), BoxSelectTool(), TapTool())

r = p.line(x, y, color="#2222aa", line_width=3)

r.data_source.callback = CustomJS(args=dict(), code="""
    var kernel = IPython.notebook.kernel;
    var inds = cb_obj.get('selected')['1d'].indices;
    IPython.notebook.kernel.execute("foo = " + inds);
    """)

# %%
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()

# %%
show(p)
# Out:
#     <div class="plotdiv" id="fe7c5ac1-9970-4c37-858a-a675df7d0923"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fe7c5ac1-9970-4c37-858a-a675df7d0923");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fe7c5ac1-9970-4c37-858a-a675df7d0923' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"31040972-e233-45b1-bb4c-e8335a0092d7":{"roots":{"references":[{"attributes":{"overlay":{"id":"f3f7aaf8-4e20-4c27-a167-4236ff087d6c","type":"BoxAnnotation"},"plot":{"id":"62a98d1d-0ef0-4a12-8c34-f1bc9d635899","subtype":"Figure","type":"Plot"}},"id":"5e840a78-77c0-407d-a9d9-b13104a9708e","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"036d2695-a516-4606-907f-746c1f29fdc6","type":"Line"},{"attributes":{"plot":{"id":"1c3aeea0-b1ca-4867-bb8b-4e9fd6fb37de","subtype":"Figure","type":"Plot"}},"id":"b99ba33d-95a1-4ab3-86c9-0f8250e22611","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"90581db1-e151-44c4-9f78-473658d7d9c1","type":"PolyAnnotation"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"4f7f61a2-93d7-47fa-aae9-0e804bb9ca26","type":"PolyAnnotation"},{"attributes":{},"id":"e805768d-0b22-4c1d-a59e-ab76dc5af1b1","type":"ToolEvents"},{"attributes":{},"id":"b609ef5e-ccb9-4f11-aba9-60a524be1030","type":"BasicTicker"},{"attributes":{},"id":"a23b7b2e-0f6e-49d1-a5c0-60d72162dc25","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"1c3aeea0-b1ca-4867-bb8b-4e9fd6fb37de","subtype":"Figure","type":"Plot"}},"id":"4d17013a-df20-4e80-be78-5ebc22fa887e","type":"HelpTool"},{"attributes":{},"id":"4a1ac446-caca-4858-a12c-e6845caac88b","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"43f315c0-2fc2-4d36-952b-7b3696119d69","type":"PolyAnnotation"},{"attributes":{"formatter":{"id":"bc8c597d-5f7d-46e0-b343-5f6780640659","type":"BasicTickFormatter"},"plot":{"id":"1c3aeea0-b1ca-4867-bb8b-4e9fd6fb37de","subtype":"Figure","type":"Plot"},"ticker":{"id":"9e01e632-2669-4099-b1ec-ed4e9f71b67b","type":"BasicTicker"}},"id":"495ccf06-1071-49df-b197-fa335ddffa90","type":"LinearAxis"},{"attributes":{"callback":null},"id":"583bee27-1381-4581-a9ea-7da209bb2562","type":"DataRange1d"},{"attributes":{"overlay":{"id":"90581db1-e151-44c4-9f78-473658d7d9c1","type":"PolyAnnotation"},"plot":{"id":"5464c5a0-787d-40d8-bedb-a380b62cdb14","subtype":"Figure","type":"Plot"}},"id":"21b77c3a-ae1d-4bb1-ac9a-9df8d0448cbb","type":"PolySelectTool"},{"attributes":{"code":"\n    var kernel = IPython.notebook.kernel;\n    var inds = cb_obj.get('selected')['1d'].indices;\n    IPython.notebook.kernel.execute(\"foo = \" + inds);\n    "},"id":"7787c567-6a7e-453a-a2fa-340b09ea6646","type":"CustomJS"},{"attributes":{},"id":"9e01e632-2669-4099-b1ec-ed4e9f71b67b","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9f66d376-a97c-4045-89e7-4caf673f0a97","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"21f3db1e-6b51-4351-a3b3-797553689c4b","type":"LinearAxis"}],"left":[{"id":"4b2bf167-6203-4d28-af73-42b6979600b4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"21f3db1e-6b51-4351-a3b3-797553689c4b","type":"LinearAxis"},{"id":"a5b93969-f878-467c-8bc7-fb7652776bcd","type":"Grid"},{"id":"4b2bf167-6203-4d28-af73-42b6979600b4","type":"LinearAxis"},{"id":"73cd3ccb-b841-4d3e-885b-ef0f86511169","type" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[21]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,5), phi=(0, 20, 0.1))
